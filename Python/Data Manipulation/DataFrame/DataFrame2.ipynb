# %%
import pandas as pd
df=pd.read_csv("/content/data2.csv")
print(df)
# Out:
#       Name Section  Roll No  Age    Year
# 0   Aditya       A        1   21   First
# 1      Sai       D        2   22  Second
# 2     Rani       C        3   22  Second
# 3    Phani       B        4   23   Third
# 4  Chandra       A        5   24   Final

# %%
df[df.columns[1:4]]
# Out:
#   Section  Roll No  Age
# 0       A        1   21
# 1       D        2   22
# 2       C        3   22
# 3       B        4   23
# 4       A        5   24

# %%
df.loc[1:3,'Name':'Year']
# Out:
#     Name Section  Roll No  Age    Year
# 1    Sai       D        2   22  Second
# 2   Rani       C        3   22  Second
# 3  Phani       B        4   23   Third

# %%
df.iloc[0:2,1:4]
# Out:
#   Section  Roll No  Age
# 0       A        1   21
# 1       D        2   22

# %%
df.insert(3, "Location", ['Delhi','Mumbai','Chennai','Vizag','Goa'])
print(df)
# Out:
#       Name Section  Roll No Location  Age    Year
# 0   Aditya       A        1    Delhi   21   First
# 1      Sai       D        2   Mumbai   22  Second
# 2     Rani       C        3  Chennai   22  Second
# 3    Phani       B        4    Vizag   23   Third
# 4  Chandra       A        5      Goa   24   Final

# %%
Grade=['A+','A','B','B+','P']
df['Grade']=Grade
print(df)
# Out:
#       Name Section  Roll No Location  Age    Year Grade
# 0   Aditya       A        1    Delhi   21   First    A+
# 1      Sai       D        2   Mumbai   22  Second     A
# 2     Rani       C        3  Chennai   22  Second     B
# 3    Phani       B        4    Vizag   23   Third    B+
# 4  Chandra       A        5      Goa   24   Final     P

# %%
df.drop(columns=['Location'], inplace=True)

# %%
print(df)
# Out:
#       Name Section  Roll No  Age    Year Grade
# 0   Aditya       A        1   21   First    A+
# 1      Sai       D        2   22  Second     A
# 2     Rani       C        3   22  Second     B
# 3    Phani       B        4   23   Third    B+
# 4  Chandra       A        5   24   Final     P

# %%
df.rename(columns={'Section':'Class'}, inplace=True)
print(df)
# Out:
#       Name Class  Roll No  Age    Year Grade
# 0   Aditya     A        1   21   First    A+
# 1      Sai     D        2   22  Second     A
# 2     Rani     C        3   22  Second     B
# 3    Phani     B        4   23   Third    B+
# 4  Chandra     A        5   24   Final     P

# %%
df.T
# Out:
#               0       1       2      3        4
# Name     Aditya     Sai    Rani  Phani  Chandra
# Class         A       D       C      B        A
# Roll No       1       2       3      4        5
# Age          21      22      22     23       24
# Year      First  Second  Second  Third    Final
# Grade        A+       A       B     B+        P
